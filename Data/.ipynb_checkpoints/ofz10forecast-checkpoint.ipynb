# %%
import scrapy
from  scrapy.http import HtmlResponse
from scrapy import Selector

import requests

# %%
from datetime import datetime

import requests
import pandas as pd
from bs4 import BeautifulSoup

URL = "https://www.cbr.ru/eng/hd_base/zcyc_params/?UniDbQuery.Posted=True&UniDbQuery.From=28.02.2022"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
results = soup.find_all("tr")
#print(results)
data_vals = []
for tr in results[2:]:
    date = datetime.strptime(tr.find_all("td")[0].text, "%d.%m.%Y")
    val = float(tr.find_all("td")[-4].text)
    data_vals.append((date, val))
#print(page.text)
#print(data)
df = pd.DataFrame(data_vals, columns = ['ds','y'])
print(df)
df.plot.line(x='ds', y='y')
# Out:
#             ds      y
# 0   2023-01-05  10.26
# 1   2023-01-04  10.28
# 2   2023-01-03  10.27
# 3   2022-12-30  10.31
# 4   2022-12-29  10.39
# ..         ...    ...
# 197 2022-03-25  13.18
# 198 2022-03-24  13.36
# 199 2022-03-23  13.63
# 200 2022-03-22  13.22
# 201 2022-03-21  13.57
#
# [202 rows x 2 columns]
# <AxesSubplot:xlabel='ds'>

# %%
from prophet import Prophet

m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=40)
future.tail()
forecast = m.predict(future)
fig1 = m.plot(forecast)
fig2 = m.plot_components(forecast)
# Out:
# 10:16:34 - cmdstanpy - INFO - Chain [1] start processing
# 10:16:34 - cmdstanpy - INFO - Chain [1] done processing

# %%
from prophet.plot import plot_plotly, plot_components_plotly
import plotly.graph_objects as go
#plot_plotly(m, forecast)
plot_components_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 4>()
#       2 import plotly.graph_objects as go
#       3 #plot_plotly(m, forecast)
# ----> 4 plot_components_plotly(m, forecast)
#
# File ~/PycharmProjects/trading/venv/lib/python3.10/site-packages/prophet/plot.py:738, in plot_components_plotly(m, fcst, uncertainty, plot_cap, figsize)
#     736 # Identify components to plot and get their Plotly props
#     737 components = {}
# --> 738 components['trend'] = get_forecast_component_plotly_props(
#     739     m, fcst, 'trend', uncertainty, plot_cap)
#     740 if m.train_holiday_names is not None and 'holidays' in fcst:
#     741     components['holidays'] = get_forecast_component_plotly_props(
#     742         m, fcst, 'holidays', uncertainty)
#
# File ~/PycharmProjects/trading/venv/lib/python3.10/site-packages/prophet/plot.py:875, in get_forecast_component_plotly_props(m, fcst, name, uncertainty, plot_cap)
#     872         text[idxs.astype(bool)] += holiday_feature
#     874 traces = []
# --> 875 traces.append(go.Scatter(
#     876     name=name,
#     877     x=fcst['ds'],
#     878     y=fcst[name],
#     879     mode=mode,
#     880     line=go.scatter.Line(color=prediction_color, width=line_width),
#     881     text=text,
#     882 ))
#     883 if uncertainty and m.uncertainty_samples and (fcst[name + '_upper'] != fcst[name + '_lower']).any():
#     884     if mode == 'markers':
#
# NameError: name 'go' is not defined

# %%
import plotly.graph_objs as go
